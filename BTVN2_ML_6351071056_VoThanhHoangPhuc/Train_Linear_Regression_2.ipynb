# %% [markdown]
# # 1. Mô tả bộ dữ liệu
# ### Nguồn dữ liệu:
# Bộ dữ liệu Recent Earthquakes được thu thập từ USGS (United States Geological Survey), cung cấp thông tin chi tiết về các trận động đất gần đây trên toàn thế giới. Dữ liệu bao gồm vị trí địa lý, độ sâu, cường độ, loại cảnh báo, và nhiều đặc trưng địa lý – hành chính kèm theo.
# ### Mục tiêu bài toán:
# Phân tích và dự đoán cường độ động đất (magnitude) dựa trên các đặc trưng liên quan đến vị trí địa lý, độ sâu, và các thông số kỹ thuật khác.
#
# → Đây là bài toán hồi quy (Regression), trong đó biến mục tiêu (target) là magnitude.
#
# ### Quy mô dữ liệu:
# - Số lượng mẫu: 1,137 bản ghi.
#
# - Số lượng thuộc tính: 40+ cột, bao gồm thông tin kỹ thuật, vị trí, và siêu dữ liệu.
#
# - Không có giá trị thiếu đáng kể ở các thuộc tính chính (như magnitude, latitude, longitude, depth).
#
# - Một số cột có tỷ lệ thiếu cao (ví dụ: postcode có hơn 80% giá trị NaN).
# ### Các thuộc tính chính:
# | Thuộc tính           | Mô tả                                              | Kiểu dữ liệu             |
# | -------------------- | -------------------------------------------------- | ------------------------ |
# | **id**               | Mã định danh duy nhất của mỗi trận động đất        | Object                   |
# | **magnitude**        | Cường độ của trận động đất theo thang Richter      | Float (Target)           |
# | **type**             | Loại sự kiện (hầu hết là “earthquake”)             | Categorical              |
# | **latitude**         | Vĩ độ tâm chấn                                     | Float                    |
# | **longitude**        | Kinh độ tâm chấn                                   | Float                    |
# | **depth**            | Độ sâu của tâm chấn (km)                           | Float                    |
# | **magType**          | Loại phép đo cường độ (mww, ml, mb, …)             | Categorical              |
# | **time**             | Thời gian xảy ra (Unix timestamp)                  | Integer                  |
# | **alert**            | Mức cảnh báo (green, yellow, orange, red)          | Categorical (có missing) |
# | **continent**        | Châu lục xảy ra động đất                           | Categorical              |
# | **country**          | Quốc gia xảy ra động đất                           | Categorical              |
# | **location / place** | Mô tả vị trí địa lý chi tiết                       | Text                     |
# | **tsunami**          | Cờ đánh dấu có xuất hiện sóng thần hay không (0/1) | Integer (Binary)         |
# | **sig**              | Mức độ nghiêm trọng (severity index)               | Integer                  |
# | **gap / rms / dmin** | Các tham số đo độ chính xác của vị trí địa chấn    | Float                    |
#
#
#
# ### Đặc điểm dữ liệu:
#
# - Dữ liệu đa dạng về không gian (các trận động đất diễn ra ở nhiều khu vực trên thế giới: Mỹ, Nhật Bản, Đài Loan, Indonesia, Chile, v.v.).
#
# - Cột magnitude dao động trong khoảng 3.0 – 7.6, phản ánh cả động đất nhỏ và trung bình – lớn.
#
# - Các cột như alert, continent, country có thể được mã hóa one-hot hoặc Label Encoding cho mô hình.
#
# - Một số cột chứa chuỗi hoặc cấu trúc JSON (locationDetails, sources, types) – nên được loại bỏ hoặc trích rút đặc trưng.
#
# - Các giá trị định lượng có quy mô rất khác nhau (ví dụ depth so với rms), cần chuẩn hóa (scaling) trước khi huấn luyện.
#
# ### Chất lượng và xử lý dữ liệu:
#
# - Giá trị thiếu:
#
#   - Cột postcode thiếu nhiều (>80%), có thể loại bỏ.
#
#   - continent, country, alert có giá trị NaN, có thể điền bằng “unknown”.
#
# - Chuẩn hóa dữ liệu số:
#
#   - Áp dụng StandardScaler hoặc MinMaxScaler cho các thuộc tính như depth, latitude, longitude, sig, rms.
#
# - Mã hóa dữ liệu phân loại:
#
#   - alert, magType, continent, country → LabelEncoder hoặc OneHotEncoder.
#
# - Loại bỏ cột trùng lặp hoặc siêu dữ liệu không cần thiết:
#
#   - Ví dụ: id, url, detailUrl, what3words, locationDetails, sources.
#
# ### Ứng dụng và phạm vi sử dụng:
#
# - Phân tích dữ liệu địa chấn: Nhận diện khu vực có hoạt động địa chấn mạnh.
#
# - Dự báo nguy cơ động đất: Xây dựng mô hình hồi quy dự đoán magnitude hoặc xác suất sóng thần (tsunami).
#
# - Nghiên cứu khoa học: Dùng làm bộ dữ liệu thực tế trong học máy về hồi quy không gian – thời gian.
#
# - Ứng dụng mô hình:
#
#   - Linear Regression
#
#   - Random Forest Regressor
#
#   - XGBoost / Gradient Boosting
#
#   - Support Vector Regressor (SVR)
#
#   - Neural Network Regressor

# %% [markdown]
# # 2. Quy trình chia dữ liệu và huấn luyện mô hình Linear Regression

# %% [markdown]
# ## 2.1 Tải và đọc dữ liệu

# %%
import kagglehub
import pandas as pd
import glob
import os

# Tải dữ liệu từ kagglehub
try:
    path = kagglehub.dataset_download("shreyasur965/recent-earthquakes")
except Exception as e:
    print(f"Lỗi khi tải dữ liệu: {e}")
    exit()

csv_files = glob.glob(os.path.join(path, '*.csv'))

if not csv_files:
    print("Không tìm thấy file CSV nào trong thư mục đã tải.")
    exit()

data_file_path = csv_files[0]
df = pd.read_csv(data_file_path)

print("  PHÂN TÍCH CÁC NHÃN/GIÁ TRỊ ĐỘC NHẤT TRONG DỮ LIỆU  ")

for col in df.columns:
    print(f"\n--- Cột: {col} (Dtype: {df[col].dtype}) ---")

    if df[col].dtype == 'object':
        print("Các nhãn/giá trị độc nhất và tần suất:")
        print(df[col].value_counts(dropna=False).head(10))
        print(f"Tổng số giá trị độc nhất: {df[col].nunique()}")

    elif df[col].dtype == 'int64':
        if df[col].nunique() <= 10:
            print("Các giá trị/nhãn số nguyên và tần suất:")
            print(df[col].value_counts(dropna=False))
        else:
            print(f"Số lượng giá trị độc nhất: {df[col].nunique()}. "
                  f"Giá trị nhỏ nhất: {df[col].min()}, Giá trị lớn nhất: {df[col].max()}.")

    elif df[col].dtype == 'float64':
        print(f"Số lượng giá trị độc nhất: {df[col].nunique()}. "
              f"Giá trị nhỏ nhất: {df[col].min()}, Giá trị lớn nhất: {df[col].max()}.")
        print(f"Tỷ lệ giá trị thiếu (NaN): {df[col].isnull().sum() / len(df) * 100:.2f}%")

print("THÔNG TIN TỔNG QUAN DỮ LIỆU:")
print(df.info())
print("\n5 dòng đầu tiên:")
print(df.head())
# Out:
# Using Colab cache for faster access to the 'recent-earthquakes' dataset.
#   PHÂN TÍCH CÁC NHÃN/GIÁ TRỊ ĐỘC NHẤT TRONG DỮ LIỆU
#
# --- Cột: id (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# id
# us6000mirj    4
# us6000nnuf    4
# us7000ndte    4
# tx2024rcoz    4
# tx2024qyag    4
# tx2024qnpx    4
# us7000n8wd    4
# tx2024scvz    4
# us6000kyb4    4
# us6000kr3t    4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 602
#
# --- Cột: magnitude (Dtype: float64) ---
# Số lượng giá trị độc nhất: 86. Giá trị nhỏ nhất: 3.0, Giá trị lớn nhất: 7.6.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: type (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# type
# earthquake    1137
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 1
#
# --- Cột: title (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# title
# M 5.5 - Izu Islands, Japan region             12
# M 5.7 - Izu Islands, Japan region             12
# M 5.3 - Izu Islands, Japan region             12
# M 5.4 - Izu Islands, Japan region             12
# M 3.5 - 54 km NW of Toyah, Texas              10
# M 6.1 - Izu Islands, Japan region              8
# M 5.8 - Izu Islands, Japan region              8
# M 5.6 - Izu Islands, Japan region              8
# M 3.3 - 56 km S of Whites City, New Mexico     6
# M 3.6 - 28 km SW of Garden City, Texas         6
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 586
#
# --- Cột: date (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# date
# 2024-09-08T02:37:22    8
# 2024-09-14T17:01:06    8
# 2024-08-03T17:24:28    8
# 2024-08-23T03:21:38    8
# 2024-07-02T23:39:59    8
# 2024-07-23T02:31:04    8
# 2024-07-03T00:04:35    8
# 2024-08-10T13:34:46    6
# 2024-09-17T00:49:42    6
# 2024-08-31T10:01:04    6
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 576
#
# --- Cột: time (Dtype: int64) ---
# Số lượng giá trị độc nhất: 602. Giá trị nhỏ nhất: 1687541953135, Giá trị lớn nhất: 1726660932699.
#
# --- Cột: updated (Dtype: int64) ---
# Số lượng giá trị độc nhất: 495. Giá trị nhỏ nhất: 1693083267040, Giá trị lớn nhất: 1726672002991.
#
# --- Cột: url (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# url
# https://earthquake.usgs.gov/earthquakes/eventpage/us6000mirj    4
# https://earthquake.usgs.gov/earthquakes/eventpage/us6000nnuf    4
# https://earthquake.usgs.gov/earthquakes/eventpage/us7000ndte    4
# https://earthquake.usgs.gov/earthquakes/eventpage/tx2024rcoz    4
# https://earthquake.usgs.gov/earthquakes/eventpage/tx2024qyag    4
# https://earthquake.usgs.gov/earthquakes/eventpage/tx2024qnpx    4
# https://earthquake.usgs.gov/earthquakes/eventpage/us7000n8wd    4
# https://earthquake.usgs.gov/earthquakes/eventpage/tx2024scvz    4
# https://earthquake.usgs.gov/earthquakes/eventpage/us6000kyb4    4
# https://earthquake.usgs.gov/earthquakes/eventpage/us6000kr3t    4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 602
#
# --- Cột: detailUrl (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# detailUrl
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000mirj&format=geojson    4
# https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000nnuf.geojson           4
# https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000ndte.geojson           4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2024rcoz&format=geojson    4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2024qyag&format=geojson    4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2024qnpx&format=geojson    4
# https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us7000n8wd.geojson           4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2024scvz&format=geojson    4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000kyb4&format=geojson    4
# https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000kr3t&format=geojson    4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 602
#
# --- Cột: felt (Dtype: int64) ---
# Số lượng giá trị độc nhất: 139. Giá trị nhỏ nhất: 0, Giá trị lớn nhất: 183786.
#
# --- Cột: cdi (Dtype: int64) ---
# Các giá trị/nhãn số nguyên và tần suất:
# cdi
# 0    365
# 3    169
# 4    156
# 5    132
# 6     79
# 2     77
# 7     59
# 1     47
# 8     30
# 9     23
# Name: count, dtype: int64
#
# --- Cột: mmi (Dtype: int64) ---
# Các giá trị/nhãn số nguyên và tần suất:
# mmi
# 4    490
# 3    210
# 5    146
# 6    105
# 7     84
# 2     42
# 1     28
# 8     26
# 9      6
# Name: count, dtype: int64
#
# --- Cột: alert (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# alert
# green     711
# NaN       373
# yellow     38
# red         9
# orange      6
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 4
#
# --- Cột: status (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# status
# reviewed     1127
# automatic       6
# REVIEWED        4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 3
#
# --- Cột: tsunami (Dtype: int64) ---
# Các giá trị/nhãn số nguyên và tần suất:
# tsunami
# 0    1069
# 1      68
# Name: count, dtype: int64
#
# --- Cột: sig (Dtype: int64) ---
# Số lượng giá trị độc nhất: 261. Giá trị nhỏ nhất: 138, Giá trị lớn nhất: 2419.
#
# --- Cột: net (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# net
# us    794
# tx    150
# ci     68
# ak     53
# nn     30
# nc     13
# ok     11
# uu      9
# at      4
# nm      3
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 11
#
# --- Cột: code (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# code
# 6000mirj    4
# 6000nnuf    4
# 7000ndte    4
# 2024rcoz    4
# 2024qyag    4
# 2024qnpx    4
# 7000n8wd    4
# 2024scvz    4
# 6000kyb4    4
# 6000kr3t    4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 602
#
# --- Cột: ids (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# ids
# ,us7000necw,tx2024shcj,                              6
# ,us7000ndte,tx2024scvz,                              4
# ,us7000ndte,                                         4
# ,us6000nnuf,tx2024rcoz,                              4
# ,us6000nnuf,                                         4
# ,tx2024rvqa,us7000ncvs,                              4
# ,us7000kwg2,usauto7000kwg2,at00s16nrn,pt23261000,    4
# ,us7000ku4z,                                         4
# ,us6000kz5s,usauto6000kz5s,pt23223000,at00rz7a0b,    4
# ,usauto6000kyb4,us6000kyb4,                          4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 599
#
# --- Cột: sources (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# sources
# ,us,                 244
# ,us,usauto,          146
# ,us,tx,              123
# ,us,usauto,pt,        85
# ,usauto,us,           74
# ,us,usauto,at,pt,     45
# ,ci,us,               43
# ,us,usauto,pt,at,     39
# ,ak,us,               38
# ,tx,us,               30
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 65
#
# --- Cột: types (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# types
# ,dyfi,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,                    111
# ,dyfi,losspager,moment-tensor,origin,phase-data,shakemap,                                           105
# ,origin,phase-data,shakemap,                                                                        104
# ,dyfi,moment-tensor,origin,phase-data,shakemap,                                                      70
# ,dyfi,internal-moment-tensor,internal-origin,losspager,moment-tensor,origin,phase-data,shakemap,     69
# ,internal-moment-tensor,losspager,moment-tensor,origin,phase-data,shakemap,                          66
# ,moment-tensor,origin,phase-data,shakemap,                                                           61
# ,losspager,origin,phase-data,shakemap,                                                               52
# ,dyfi,origin,phase-data,shakemap,                                                                    50
# ,dyfi,losspager,origin,phase-data,shakemap,                                                          40
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 94
#
# --- Cột: nst (Dtype: int64) ---
# Số lượng giá trị độc nhất: 232. Giá trị nhỏ nhất: 0, Giá trị lớn nhất: 619.
#
# --- Cột: dmin (Dtype: float64) ---
# Số lượng giá trị độc nhất: 452. Giá trị nhỏ nhất: 0.0, Giá trị lớn nhất: 12.457.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: rms (Dtype: float64) ---
# Số lượng giá trị độc nhất: 130. Giá trị nhỏ nhất: 0.0, Giá trị lớn nhất: 2.52.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: gap (Dtype: float64) ---
# Số lượng giá trị độc nhất: 149. Giá trị nhỏ nhất: 0.0, Giá trị lớn nhất: 256.0.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: magType (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# magType
# mww      551
# ml       351
# mb       124
# mwr       53
# mw        36
# mb_lg     16
# mwb        2
# Ml         2
# Mi         2
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 9
#
# --- Cột: geometryType (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# geometryType
# Point    1137
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 1
#
# --- Cột: depth (Dtype: float64) ---
# Số lượng giá trị độc nhất: 432. Giá trị nhỏ nhất: -0.25, Giá trị lớn nhất: 639.503.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: latitude (Dtype: float64) ---
# Số lượng giá trị độc nhất: 589. Giá trị nhỏ nhất: -43.7064, Giá trị lớn nhất: 68.1761.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: longitude (Dtype: float64) ---
# Số lượng giá trị độc nhất: 590. Giá trị nhỏ nhất: -179.807, Giá trị lớn nhất: 179.972.
# Tỷ lệ giá trị thiếu (NaN): 0.00%
#
# --- Cột: place (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# place
# Izu Islands, Japan region             76
# 56 km S of Whites City, New Mexico    20
# 54 km NW of Toyah, Texas              18
# 57 km S of Whites City, New Mexico    16
# 55 km S of Whites City, New Mexico    14
# 58 km S of Whites City, New Mexico    12
# 55 km NW of Toyah, Texas              10
# 28 km SW of Garden City, Texas         9
# Volcano Islands, Japan region          8
# Bonin Islands, Japan region            8
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 518
#
# --- Cột: distanceKM (Dtype: int64) ---
# Số lượng giá trị độc nhất: 173. Giá trị nhỏ nhất: 0, Giá trị lớn nhất: 298.
#
# --- Cột: placeOnly (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# placeOnly
# S of Whites City, New Mexico     88
# Izu Islands, Japan region        76
# NW of Toyah, Texas               32
# S of Hualien City, Taiwan        18
# NNE of Hermleigh, Texas          17
# NE of Anamizu, Japan             16
# ENE of Walker Lake, Nevada       14
# NW of Grapevine, CA              12
# WNW of Aykol, China              12
# ENE of Barcelona, Philippines    10
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 353
#
# --- Cột: location (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# location
# Whites City, New Mexico      98
# Izu Islands, Japan region    76
# Hualien City, Taiwan         50
# Toyah, Texas                 39
# Anamizu, Japan               28
# Hermleigh, Texas             25
# Falls City, Texas            20
# Barcelona, Philippines       19
# Walker Lake, Nevada          18
# Atka, Alaska                 16
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 270
#
# --- Cột: continent (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# continent
# North America      446
# Asia               333
# NaN                270
# South America       75
# Europe               7
# Africa               3
# Insular Oceania      1
# Insluar Oceania      1
# Oceania              1
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 8
#
# --- Cột: country (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# country
# United States of America (the)    423
# NaN                               338
# Japan                              68
# Taiwan (Province of China)         55
# Indonesia                          38
# China                              30
# Chile                              29
# Argentina                          26
# Afghanistan                        26
# Philippines (the)                  17
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 31
#
# --- Cột: subnational (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# subnational
# NaN                                  421
# Texas                                222
# California                            75
# Nevada                                40
# Alaska                                37
# Ishikawa                              32
# Xinjiang Uyghur Autonomous Region     22
# Herat                                 14
# Oklahoma                              13
# Hualien                               10
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 100
#
# --- Cột: city (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# city
# NaN               463
# Van Horn          130
# Hawthorne          24
# Suzu               20
# Falls City         20
# Pecos              17
# West Kern          15
# Los Angeles        14
# Snyder             14
# Tarzan-Lenorah     12
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 167
#
# --- Cột: locality (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# locality
# Etc/GMT-9           121
# Van Horn             90
# Etc/GMT-8            59
# Etc/GMT-10           43
# Taiwan               40
# Culberson County     40
# Etc/GMT+11           36
# Hawthorne            24
# Falls City           20
# Pecos                17
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 224
#
# --- Cột: postcode (Dtype: float64) ---
# Số lượng giá trị độc nhất: 57. Giá trị nhỏ nhất: 8833.0, Giá trị lớn nhất: 99827.0.
# Tỷ lệ giá trị thiếu (NaN): 82.67%
#
# --- Cột: what3words (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# what3words
# untied.disadvantaged.sittings       4
# disputes.penniless.unwind           4
# spinners.downtime.computes          4
# works.saxophone.tomb                4
# owls.mystic.laterally               4
# pioneered.keyboards.cracked         4
# feather.love.editions               4
# sailboats.sawn.speeding             4
# midlist.passports.pierces           4
# regurgitate.grimaced.calculating    4
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 602
#
# --- Cột: timezone (Dtype: int64) ---
# Số lượng giá trị độc nhất: 28. Giá trị nhỏ nhất: -720, Giá trị lớn nhất: 780.
#
# --- Cột: locationDetails (Dtype: object) ---
# Các nhãn/giá trị độc nhất và tần suất:
# locationDetails
# [{'id': '9', 'wikidataId': 'Q49', 'name': 'North America', 'description': "continent on the Earth's northwestern quadrant", 'geonameId': '6255149', 'adminLevel': '0'}, {'id': '87153', 'wikidataId': '', 'name': 'America/Chicago', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '89129', 'wikidataId': '', 'name': '48-109-94015', 'description': 'FIPS code', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86034', 'wikidataId': 'Q30', 'name': 'United States of America (the)', 'description': 'country in North America', 'geonameId': '6252001', 'adminLevel': '2'}, {'id': '161', 'wikidataId': 'Q1439', 'name': 'Texas', 'description': 'State in the southern United States', 'geonameId': '4736286', 'adminLevel': '4'}, {'id': '162', 'wikidataId': 'Q108607', 'name': 'Culberson County', 'description': 'county in Texas, United States', 'geonameId': '5519788', 'adminLevel': '6'}, {'id': '87565', 'wikidataId': 'Q976246', 'name': 'Van Horn', 'description': 'town in and the seat of Culberson County, Texas, United States', 'geonameId': '5532924', 'adminLevel': '8'}]                                                                                                                                                                                                  60
# [{'id': '86373', 'wikidataId': 'Q1964385', 'name': 'Nanpo Islands', 'description': 'Japanese term 南方諸島 (literally "southern islands"). indefinitely refers Izu and Ogasawara Islands', 'geonameId': '2111702', 'adminLevel': '0'}, {'id': '87155', 'wikidataId': '', 'name': 'Etc/GMT-9', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '315', 'wikidataId': 'Q159183', 'name': 'Philippine Sea', 'description': 'sea located east and northeast of the Philippines', 'geonameId': '1818190', 'adminLevel': '0'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                45
# [{'id': '89129', 'wikidataId': '', 'name': '48-109-94015', 'description': 'FIPS code', 'geonameId': '0', 'adminLevel': '0'}, {'id': '9', 'wikidataId': 'Q49', 'name': 'North America', 'description': "continent on the Earth's northwestern quadrant", 'geonameId': '6255149', 'adminLevel': '0'}, {'id': '36', 'wikidataId': 'Q578170', 'name': 'contiguous United States', 'description': '48 states of the United States apart from Alaska and Hawaii', 'geonameId': '0', 'adminLevel': '0'}, {'id': '87153', 'wikidataId': '', 'name': 'America/Chicago', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86034', 'wikidataId': 'Q30', 'name': 'United States of America (the)', 'description': 'country in North America', 'geonameId': '6252001', 'adminLevel': '2'}, {'id': '161', 'wikidataId': 'Q1439', 'name': 'Texas', 'description': 'State in the southern United States', 'geonameId': '4736286', 'adminLevel': '4'}, {'id': '162', 'wikidataId': 'Q108607', 'name': 'Culberson County', 'description': 'county in Texas, United States', 'geonameId': '5519788', 'adminLevel': '6'}, {'id': '87565', 'wikidataId': 'Q976246', 'name': 'Van Horn', 'description': 'town in and the seat of Culberson County, Texas, United States', 'geonameId': '5532924', 'adminLevel': '8'}]    41
# [{'id': '9', 'wikidataId': 'Q49', 'name': 'North America', 'description': "continent on the Earth's northwestern quadrant", 'geonameId': '6255149', 'adminLevel': '0'}, {'id': '36', 'wikidataId': 'Q578170', 'name': 'contiguous United States', 'description': '48 states of the United States apart from Alaska and Hawaii', 'geonameId': '0', 'adminLevel': '0'}, {'id': '87153', 'wikidataId': '', 'name': 'America/Chicago', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '89129', 'wikidataId': '', 'name': '48-109-94015', 'description': 'FIPS code', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86034', 'wikidataId': 'Q30', 'name': 'United States of America (the)', 'description': 'country in North America', 'geonameId': '6252001', 'adminLevel': '2'}, {'id': '161', 'wikidataId': 'Q1439', 'name': 'Texas', 'description': 'State in the southern United States', 'geonameId': '4736286', 'adminLevel': '4'}, {'id': '162', 'wikidataId': 'Q108607', 'name': 'Culberson County', 'description': 'county in Texas, United States', 'geonameId': '5519788', 'adminLevel': '6'}, {'id': '87565', 'wikidataId': 'Q976246', 'name': 'Van Horn', 'description': 'town in and the seat of Culberson County, Texas, United States', 'geonameId': '5532924', 'adminLevel': '8'}]    29
# [{'id': '108', 'wikidataId': 'Q48', 'name': 'Asia', 'description': "continent, mainly on the Earth's northeastern quadrant", 'geonameId': '6255147', 'adminLevel': '0'}, {'id': '315', 'wikidataId': 'Q159183', 'name': 'Philippine Sea', 'description': 'sea located east and northeast of the Philippines', 'geonameId': '1818190', 'adminLevel': '0'}, {'id': '87203', 'wikidataId': '', 'name': 'Asia/Taipei', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '87713', 'wikidataId': 'Q7676514', 'name': 'Taiwan', 'description': 'controversial term that describes Taiwan and its related territories as part of China', 'geonameId': '7280291', 'adminLevel': '2'}, {'id': '86099', 'wikidataId': 'Q865', 'name': 'Taiwan (Province of China)', 'description': 'country in East Asia', 'geonameId': '1668284', 'adminLevel': '2'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                         25
# [{'id': '108', 'wikidataId': 'Q48', 'name': 'Asia', 'description': "continent, mainly on the Earth's northeastern quadrant", 'geonameId': '6255147', 'adminLevel': '0'}, {'id': '315', 'wikidataId': 'Q159183', 'name': 'Philippine Sea', 'description': 'sea located east and northeast of the Philippines', 'geonameId': '1818190', 'adminLevel': '0'}, {'id': '87203', 'wikidataId': '', 'name': 'Asia/Taipei', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86099', 'wikidataId': 'Q865', 'name': 'Taiwan (Province of China)', 'description': 'country in East Asia', 'geonameId': '1668284', 'adminLevel': '2'}, {'id': '87713', 'wikidataId': 'Q7676514', 'name': 'Taiwan', 'description': 'controversial term that describes Taiwan and its related territories as part of China', 'geonameId': '7280291', 'adminLevel': '2'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                         19
# [{'id': '87208', 'wikidataId': '', 'name': 'Etc/GMT+11', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86035', 'wikidataId': 'Q12353254', 'name': 'Pacific Ocean', 'description': 'northern part of the Pacific Ocean', 'geonameId': '4030875', 'adminLevel': '0'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             19
# [{'id': '9', 'wikidataId': 'Q49', 'name': 'North America', 'description': "continent on the Earth's northwestern quadrant", 'geonameId': '6255149', 'adminLevel': '0'}, {'id': '87146', 'wikidataId': '', 'name': 'America/Los_Angeles', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '89086', 'wikidataId': '', 'name': '32-021-94434', 'description': 'FIPS code', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86034', 'wikidataId': 'Q30', 'name': 'United States of America (the)', 'description': 'country in North America', 'geonameId': '6252001', 'adminLevel': '2'}, {'id': '3', 'wikidataId': 'Q1227', 'name': 'Nevada', 'description': 'state of the United States of America', 'geonameId': '5509151', 'adminLevel': '4'}, {'id': '126', 'wikidataId': 'Q203022', 'name': 'Mineral County', 'description': 'county in Nevada, United States', 'geonameId': '5508393', 'adminLevel': '6'}, {'id': '79036', 'wikidataId': 'Q1776138', 'name': 'Hawthorne', 'description': 'census-designated place in Nevada, United States', 'geonameId': '5505321', 'adminLevel': '8'}]                                                                                                                                                                                                          18
# [{'id': '315', 'wikidataId': 'Q159183', 'name': 'Philippine Sea', 'description': 'sea located east and northeast of the Philippines', 'geonameId': '1818190', 'adminLevel': '0'}, {'id': '86373', 'wikidataId': 'Q1964385', 'name': 'Nanpo Islands', 'description': 'Japanese term 南方諸島 (literally "southern islands"). indefinitely refers Izu and Ogasawara Islands', 'geonameId': '2111702', 'adminLevel': '0'}, {'id': '87155', 'wikidataId': '', 'name': 'Etc/GMT-9', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                15
# [{'id': '87152', 'wikidataId': '', 'name': 'Etc/GMT-10', 'description': 'time zone', 'geonameId': '0', 'adminLevel': '0'}, {'id': '86035', 'wikidataId': 'Q12353254', 'name': 'Pacific Ocean', 'description': 'northern part of the Pacific Ocean', 'geonameId': '4030875', 'adminLevel': '0'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             15
# Name: count, dtype: int64
# Tổng số giá trị độc nhất: 401
# THÔNG TIN TỔNG QUAN DỮ LIỆU:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1137 entries, 0 to 1136
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1137 non-null   object
#  1   magnitude        1137 non-null   float64
#  2   type             1137 non-null   object
#  3   title            1137 non-null   object
#  4   date             1137 non-null   object
#  5   time             1137 non-null   int64
#  6   updated          1137 non-null   int64
#  7   url              1137 non-null   object
#  8   detailUrl        1137 non-null   object
#  9   felt             1137 non-null   int64
#  10  cdi              1137 non-null   int64
#  11  mmi              1137 non-null   int64
#  12  alert            764 non-null    object
#  13  status           1137 non-null   object
#  14  tsunami          1137 non-null   int64
#  15  sig              1137 non-null   int64
#  16  net              1137 non-null   object
#  17  code             1137 non-null   object
#  18  ids              1137 non-null   object
#  19  sources          1137 non-null   object
#  20  types            1137 non-null   object
#  21  nst              1137 non-null   int64
#  22  dmin             1137 non-null   float64
#  23  rms              1137 non-null   float64
#  24  gap              1137 non-null   float64
#  25  magType          1137 non-null   object
#  26  geometryType     1137 non-null   object
#  27  depth            1137 non-null   float64
#  28  latitude         1137 non-null   float64
#  29  longitude        1137 non-null   float64
#  30  place            1137 non-null   object
#  31  distanceKM       1137 non-null   int64
#  32  placeOnly        1137 non-null   object
#  33  location         1137 non-null   object
#  34  continent        867 non-null    object
#  35  country          799 non-null    object
#  36  subnational      716 non-null    object
#  37  city             674 non-null    object
#  38  locality         1137 non-null   object
#  39  postcode         197 non-null    float64
#  40  what3words       1137 non-null   object
#  41  timezone         1137 non-null   int64
#  42  locationDetails  1137 non-null   object
# dtypes: float64(8), int64(10), object(25)
# memory usage: 382.1+ KB
# None
#
# 5 dòng đầu tiên:
#            id  magnitude        type  \
# 0  us7000necw        4.8  earthquake
# 1  tx2024shcj        5.1  earthquake
# 2  ci40734823        3.7  earthquake
# 3  tx2024scvz        3.9  earthquake
# 4  us7000ndte        4.1  earthquake
#
#                                         title                 date  \
# 0         M 4.8 - 33 km WSW of Ackerly, Texas  2024-09-17T00:49:42
# 1         M 5.1 - 34 km WSW of Ackerly, Texas  2024-09-17T00:49:42
# 2                M 3.7 - 6 km N of Malibu, CA  2024-09-16T11:22:08
# 3  M 3.9 - 58 km S of Whites City, New Mexico  2024-09-14T17:01:06
# 4  M 4.1 - 60 km S of Whites City, New Mexico  2024-09-14T17:01:06
#
#             time        updated  \
# 0  1726534182289  1726583895255
# 1  1726534182183  1726672002991
# 2  1726485728190  1726637414586
# 3  1726333266539  1726584426218
# 4  1726333266382  1726334616179
#
#                                                  url  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                            detailUrl  felt  ...  \
# 0  https://earthquake.usgs.gov/earthquakes/feed/v...  1893  ...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  2042  ...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...  1580  ...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...     5  ...
# 4  https://earthquake.usgs.gov/earthquakes/feed/v...     4  ...
#
#                   location      continent                         country  \
# 0           Ackerly, Texas  North America  United States of America (the)
# 1           Ackerly, Texas  North America  United States of America (the)
# 2               Malibu, CA  North America  United States of America (the)
# 3  Whites City, New Mexico  North America  United States of America (the)
# 4  Whites City, New Mexico  North America  United States of America (the)
#
#   subnational            city             locality postcode  \
# 0       Texas  Tarzan-Lenorah       Tarzan-Lenorah  79783.0
# 1       Texas  Tarzan-Lenorah       Tarzan-Lenorah  79331.0
# 2  California     Los Angeles  Agoura Hills-Malibu  90265.0
# 3       Texas        Van Horn             Van Horn      NaN
# 4       Texas        Van Horn             Van Horn      NaN
#
#                    what3words timezone  \
# 0    landmass.perkily.affords     -300
# 1    escalator.grownups.dwell     -300
# 2    clocking.uploaded.issuer     -420
# 3     sailboats.sawn.speeding     -300
# 4  spinners.downtime.computes     -300
#
#                                      locationDetails
# 0  [{'id': '80684', 'wikidataId': '', 'name': '79...
# 1  [{'id': '89341', 'wikidataId': '', 'name': '48...
# 2  [{'id': '93478', 'wikidataId': 'Q844837', 'nam...
# 3  [{'id': '9', 'wikidataId': 'Q49', 'name': 'Nor...
# 4  [{'id': '9', 'wikidataId': 'Q49', 'name': 'Nor...
#
# [5 rows x 43 columns]

# %% [markdown]
# ## 2.2 Kiểm tra thông tin và xử lý dữ liệu

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Giả định dữ liệu đã tải sẵn vào biến df
print("THÔNG TIN TỔNG QUAN:")
df.info()

print("\nKIỂM TRA GIÁ TRỊ THIẾU:")
print(df.isnull().sum().sort_values(ascending=False).head(10))

# Giữ lại một số cột phù hợp cho bài toán hồi quy (magnitude là biến mục tiêu)
columns_to_keep = [
    'depth', 'latitude', 'longitude', 'rms', 'gap', 'dmin',
    'sig', 'nst', 'distanceKM', 'tsunami', 'mmi', 'cdi', 'magnitude'
]
df = df[columns_to_keep].copy()

# Xử lý giá trị thiếu
df = df.fillna(df.median(numeric_only=True))

# Loại bỏ hàng bị thiếu nghiêm trọng
df = df.dropna()

# Kiểm tra kiểu dữ liệu
print("\nDỮ LIỆU SAU KHI XỬ LÝ:")
print(df.describe().T)

# Biến mục tiêu
target_col = 'magnitude'
# Out:
# THÔNG TIN TỔNG QUAN:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1137 entries, 0 to 1136
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1137 non-null   object
#  1   magnitude        1137 non-null   float64
#  2   type             1137 non-null   object
#  3   title            1137 non-null   object
#  4   date             1137 non-null   object
#  5   time             1137 non-null   int64
#  6   updated          1137 non-null   int64
#  7   url              1137 non-null   object
#  8   detailUrl        1137 non-null   object
#  9   felt             1137 non-null   int64
#  10  cdi              1137 non-null   int64
#  11  mmi              1137 non-null   int64
#  12  alert            764 non-null    object
#  13  status           1137 non-null   object
#  14  tsunami          1137 non-null   int64
#  15  sig              1137 non-null   int64
#  16  net              1137 non-null   object
#  17  code             1137 non-null   object
#  18  ids              1137 non-null   object
#  19  sources          1137 non-null   object
#  20  types            1137 non-null   object
#  21  nst              1137 non-null   int64
#  22  dmin             1137 non-null   float64
#  23  rms              1137 non-null   float64
#  24  gap              1137 non-null   float64
#  25  magType          1137 non-null   object
#  26  geometryType     1137 non-null   object
#  27  depth            1137 non-null   float64
#  28  latitude         1137 non-null   float64
#  29  longitude        1137 non-null   float64
#  30  place            1137 non-null   object
#  31  distanceKM       1137 non-null   int64
#  32  placeOnly        1137 non-null   object
#  33  location         1137 non-null   object
#  34  continent        867 non-null    object
#  35  country          799 non-null    object
#  36  subnational      716 non-null    object
#  37  city             674 non-null    object
#  38  locality         1137 non-null   object
#  39  postcode         197 non-null    float64
#  40  what3words       1137 non-null   object
#  41  timezone         1137 non-null   int64
#  42  locationDetails  1137 non-null   object
# dtypes: float64(8), int64(10), object(25)
# memory usage: 382.1+ KB
#
# KIỂM TRA GIÁ TRỊ THIẾU:
# postcode       940
# city           463
# subnational    421
# alert          373
# country        338
# continent      270
# date             0
# title            0
# id               0
# magnitude        0
# dtype: int64
#
# DỮ LIỆU SAU KHI XỬ LÝ:
#              count        mean         std       min       25%       50%  \
# depth       1137.0   41.287300   87.866489   -0.2500    7.5500   10.0000
# latitude    1137.0   27.308909   20.133139  -43.7064   24.1954   31.6677
# longitude   1137.0   -3.930635  118.043697 -179.8070 -104.4520  -68.6820
# rms         1137.0    0.585974    0.308556    0.0000    0.3000    0.6300
# gap         1137.0   55.055286   37.609237    0.0000   30.0000   49.0000
# dmin        1137.0    1.342604    1.704364    0.0000    0.1000    0.6800
# sig         1137.0  432.698329  256.177844  138.0000  234.0000  449.0000
# nst         1137.0  115.094107   91.877870    0.0000   37.0000  102.0000
# distanceKM  1137.0   52.289358   56.027469    0.0000   15.0000   37.0000
# tsunami     1137.0    0.059807    0.237232    0.0000    0.0000    0.0000
# mmi         1137.0    4.320141    1.453949    1.0000    4.0000    4.0000
# cdi         1137.0    2.925242    2.562707    0.0000    0.0000    3.0000
# magnitude   1137.0    4.856675    1.047840    3.0000    3.8000    5.3000
#
#                  75%        max
# depth        34.7230   639.5030
# latitude     37.4976    68.1761
# longitude   126.6280   179.9720
# rms           0.7800     2.5200
# gap          68.0000   256.0000
# dmin          2.0610    12.4570
# sig         518.0000  2419.0000
# nst         157.0000   619.0000
# distanceKM   61.0000   298.0000
# tsunami       0.0000     1.0000
# mmi           5.0000     9.0000
# cdi           5.0000     9.0000
# magnitude     5.6000     7.6000

# %% [markdown]
# ## 2.3 Chia dữ liệu

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Tách biến đầu vào và mục tiêu
X = df.drop(columns=[target_col])
y = df[target_col]

# Chia 70% train, 30% test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Chuẩn hóa dữ liệu
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Kích thước tập huấn luyện:", X_train.shape)
print("Kích thước tập kiểm tra:", X_test.shape)
# Out:
# Kích thước tập huấn luyện: (795, 12)
# Kích thước tập kiểm tra: (342, 12)

# %% [markdown]
# ## 2.4 Huấn luyện mô hình Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Khởi tạo và huấn luyện
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Dự đoán
y_pred = lr_model.predict(X_test)

# %% [markdown]
# ## 2.5 Đánh giá mô hình

# %%
# Đánh giá mô hình
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("   KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH LINEAR REGRESSION")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"R² Score: {r2:.3f}")

# In hệ số hồi quy
print("\nHệ số hồi quy (Coefficients):")
for name, coef in zip(df.drop(columns=['magnitude']).columns, lr_model.coef_):
    print(f"{name}: {coef:.3f}")
print(f"\nHệ số chặn (Intercept): {lr_model.intercept_:.3f}")
# Out:
#    KẾT QUẢ ĐÁNH GIÁ MÔ HÌNH LINEAR REGRESSION
# Mean Squared Error (MSE): 0.11
# R² Score: 0.894
#
# Hệ số hồi quy (Coefficients):
# depth: 0.117
# latitude: -0.139
# longitude: 0.383
# rms: 0.208
# gap: 0.034
# dmin: 0.104
# sig: 0.271
# nst: 0.106
# distanceKM: 0.098
# tsunami: 0.141
# mmi: 0.130
# cdi: 0.062
#
# Hệ số chặn (Intercept): 4.884
